# %%
import pandas as pd
import numpy as np

# %%
#csv_file_name = 'csv_single_pipe_test.csv'
csv_file_name = 'csv_single_pipe_spaced_test.csv'
csv_path = 'c:/Users/luisc/Desktop/Web_Scrapers/Web_Scraping_ML/Top_ML_Products_per_Cat/'

# %%
pd.read_csv((csv_path + csv_file_name), encoding = "UTF-8", sep = "|")
# Out:
#        search_id     region    \
# 0                1       MX
# 1                2       MX
# 2                3       MX
# 3                4       MX
# 4                5       MX
# ...            ...        ...
# 1018          1019       MX
# 1019          1020       MX
# 1020          1021       MX
# 1021          1022       MX
# 1022          1023       MX
#
#                                           product_url    \
# 0       https://articulo.mercadolibre.com.mx/MLM-762...
# 1       https://articulo.mercadolibre.com.mx/MLM-782...
# 2       https://articulo.mercadolibre.com.mx/MLM-764...
# 3       https://articulo.mercadolibre.com.mx/MLM-793...
# 4       https://articulo.mercadolibre.com.mx/MLM-742...
# ...                                                 ...
# 1018    https://articulo.mercadolibre.com.mx/MLM-660...
# 1019    https://articulo.mercadolibre.com.mx/MLM-770...
# 1020    https://articulo.mercadolibre.com.mx/MLM-691...
# ...
